# %%
#3 个参数的 regplot + 相关系数（连续特征）
#三张图必须分开 plt.show()，否则叠画。
# for 循环里打印 2×2 矩阵——可改 .iloc[0,1] 更清晰。
for param in ['CPU_frequency','Screen_Size_inch','Weight_pounds']:
 sns.regplot(x=param, y='Price', data=df)
 plt.ylim(0,)
 plt.show()
#  print(f'Correlation of Price and {param} is ', df[[param,'Price']].corr().iloc[0,1])
# 四个数里有三个是废话：对角线恒为 1，另一个非对角元素和它是重复的。真正想要的只有 -0.0568 这一个值。
# 但其中真正有用的只有一个数——用 .iloc[0,1] 可以直接把这个数抠出来，输出更干净。
# .iloc 是 pandas 的纯位置索引器——按“第几行、第几列”的整数坐标取值，完全不看行名列名
# [0, 1]	第 0 行、第 1 列交叉的那个单元格
 print(f'Correlation of Price and {param} is ', df[[param,'Price']].corr())

sns.regplot(x="CPU_frequency", y="Price", data=df)
plt.ylim(0,)
sns.regplot(x="Screen_Size_inch", y="Price", data=df)
plt.ylim(0,)
sns.regplot(x="Weight_pounds", y="Price", data=df)
plt.ylim(0,)
for param in ["CPU_frequency", "Screen_Size_inch","Weight_pounds"]:
    print(f"Correlation of Price and {param} is ", df[[param,"Price"]].corr())

#类别特征
sns.boxplot(x="Category", y="Price", data=df)
sns.boxplot(x="GPU", y="Price", data=df)
sns.boxplot(x="OS", y="Price", data=df)
sns.boxplot(x="CPU_core", y="Price", data=df)
sns.boxplot(x="RAM_GB", y="Price", data=df)
sns.boxplot(x="Storage_GB_SSD", y="Price", data=df)

#  for c in ['Category','GPU','OS','CPU_core','RAM_GB','Storage_GB_SSD']:
#     sns.boxplot(x=c, y='Price', data=df); plt.show()
