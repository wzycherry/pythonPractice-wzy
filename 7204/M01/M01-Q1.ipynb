# %%
#第一个问题，打印df的最后十行，其实就是取auto.csv的最后十行，直接使用tail方法即可
#df是DataFrame格式，所以可以直接调用DF的各种方法比如tail、head
print("The last 10 rows of the dataframe\n")
df.tail(10)

#加一个问题，打印df的前5行，直接使用head方法 df.head()，默认打印前五行
print("The first 5 rows of the dataframe")
df.head(5)

#数据清洗，因为auto.csv是脏数据，连表头都没有，所以读取数据后，我们后面一步就是要进行数据清洗，让脏数据变成干净优质的数据
#我们先增加表头
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)

#将变量 headers 中存储的列名列表赋值给 DataFrame df 的列名。因此第一个df.columns（变量）表示手动添加列名，然后打印列名df.columns（方法）
df.columns = headers
df.columns
df.head(10)

#接着我们将表中的？全部清理掉，将？变成NaN，并且将price缺失行删除（NaN表示无，price缺失行其实就是price为？的行数）
df1=df.replace('?',np.nan)
#df1.dropna(...)：从 df1 中删除含有缺失值的行/列。括号里面的是条件
#subset=["price"]只检查 "price" 这一列是否有缺失值（NaN）。其他列即使有缺失值也不受影响。
#axis=0：表示按行删除（即删除的是行，不是列）。这是默认值，写出来是为了语义清晰。
#df = ...：将删除后的结果覆盖回 df。
df=df1.dropna(subset=["price"], axis=0)
df.head(20)
