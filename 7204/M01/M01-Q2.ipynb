# %%
#找出 dataframe 各列的名称，检验一下表头对不对，如果表头不对，那么全部完蛋，先标准输出表头
print(df.columns)
#将auto.csv改个名字保存为csv格式，名字改成automobile.csv，并且不要索引；index=False：保存时不写入行索引（即不把 0, 1, 2, 3... 这些行号写入文件）。如果不设置这个参数，CSV 文件会多出一列无用的索引列。
df.to_csv("automobile.csv", index=False)

#通过 dtypes 可以检查数据类型是否合理。例如：price 应该是 float64（数值），如果显示 object，说明该列中还混有非数值字符（如之前的 ?），需要进一步清洗。horsepower 如果显示 object 而非 float64，说明其中也含有非数值内容，需要转换。
df.dtypes
#打印一下类型
print(df.dtypes)

#这行代码的作用是：生成 DataFrame df 中所有数值列的统计摘要。
#只对数值列（int64、float64）进行统计，字符串列（object）会被自动忽略。如果想让 describe() 也显示字符串列的统计信息，可以加参数：df.describe(include="all")
#统计指标为 count	非缺失值的数量；mean	均值；std	标准差；min	最小值；max	最大值；25%	第 25 百分位数（下四分位数）；50%	第 50 百分位数（中位数）；75%	第 75 百分位数（上四分位数）;unique	不重复值的个数;top	出现次数最多的值（众数）;freq	top 对应的值出现的次数
df.describe()
df.describe(include = "all")
