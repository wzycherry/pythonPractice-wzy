# %%
# 解决问题：对 length 与 compression-ratio 两列应用 .describe()
#这行代码的作用是：只对 length（车身长度）和 compression-ratio（压缩比）这两列进行统计描述。
#如果df要对多个列进行处理，那么就需要多加一个[]
df[['length', 'compression-ratio']].describe()

#打印 DataFrame df 的概要信息，包括：行数和列数、每列的非空值数量、每列的数据类型、内存占用
df.info()
